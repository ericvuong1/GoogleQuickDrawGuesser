# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# %%
import os
print(os.listdir("../dataset/"))
# Out:
# ['train_labels.csv', '.DS_Store', 'train_images.npy', 'test_images.npy', 'sample_submission.csv']

# %%
#Load images with numpy
images = np.load('../dataset/train_images.npy', encoding='bytes')
images.shape
# Out:
# (10000, 2)

# %%
#Reshaping image to 100x100
image1 = (images[0][1]).reshape(100,100)
plt.imshow(image1)

# %%
y_train = pd.read_csv('../dataset/train_labels.csv');

# %%
y_train
# Out:
#         Id      Category
# 0        0        shovel
# 1        1         rifle
# 2        2      scorpion
# 3        3         apple
# 4        4         spoon
# 5        5     pineapple
# 6        6         rifle
# 7        7         mouth
# 8        8    skateboard
# 9        9  rollerskates
# 10      10        peanut
# 11      11        rabbit
# 12      12          sink
# 13      13      sailboat
# 14      14          nose
# 15      15          nose
# 16      16         skull
# 17      17         mouth
# 18      18          pool
# 19      19         mouth
# 20      20        peanut
# 21      21         rifle
# 22      22          pear
# 23      23      scorpion
# 24      24        pillow
# 25      25       penguin
# 26      26         skull
# 27      27    skateboard
# 28      28          nail
# 29      29        pencil
# ...    ...           ...
# 9970  9970    paintbrush
# 9971  9971          nail
# 9972  9972         empty
# 9973  9973    paintbrush
# 9974  9974       octagon
# 9975  9975          nail
# 9976  9976           mug
# 9977  9977        peanut
# 9978  9978     pineapple
# 9979  9979          nail
# 9980  9980     moustache
# 9981  9981          pool
# 9982  9982          pool
# 9983  9983       penguin
# 9984  9984      scorpion
# 9985  9985         spoon
# 9986  9986         empty
# 9987  9987  rollerskates
# 9988  9988  rollerskates
# 9989  9989     moustache
# 9990  9990         rifle
# 9991  9991    paintbrush
# 9992  9992           mug
# 9993  9993        pillow
# 9994  9994    skateboard
# 9995  9995          pool
# 9996  9996         apple
# 9997  9997  rollerskates
# 9998  9998         mouth
# 9999  9999        pencil
#
# [10000 rows x 2 columns]
